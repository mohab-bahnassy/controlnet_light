# %% [markdown]
# # ControlNet Lightweight Training on Google Colab
#
# This notebook trains a lightweight ControlNet model and saves it to Google Drive.
#
# **Recommended Runtime:** GPU (T4 or better)
#
# **Estimated Time:** 2-6 hours depending on dataset size

# %% [markdown]
# ## Step 1: Mount Google Drive
